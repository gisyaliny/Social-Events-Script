# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Get-all-types-of-events" data-toc-modified-id="Get-all-types-of-events-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Get all types of events</a></span><ul class="toc-item"><li><span><a href="#Family-events" data-toc-modified-id="Family-events-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span><a href="https://www.meetup.com/find/us--tx--dallas/parents-family" target="_blank">Family events</a></a></span></li><li><span><a href="#Outdoors-&amp;-Adventure-events" data-toc-modified-id="Outdoors-&amp;-Adventure-events-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span><a href="https://www.meetup.com/find/outdoors-adventure" target="_blank">Outdoors &amp; Adventure events</a></a></span></li><li><span><a href="#Downloader" data-toc-modified-id="Downloader-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Downloader</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Get events data from [meetup](https://www.meetup.com/)

# %% [markdown]
# ## Get all types of events

# %%
import sys
sys.path.append(r'F:\geostats')

from geostats import Scraping
from get_groupinfo import *
from get_eventsInfo import *
from urllib.error import HTTPError
import time,random,os

# %%
opener = Scraping.setProxy()
urllib.request.install_opener(opener)

# %%
url = "https://www.meetup.com/"
content = Scraping.parseHtml(url)
Categories = content.xpath('///*[@id="gatsby-focus-wrapper"]//a/div/div//text()')
# Sub_Url_10miles = list(content.xpath('//*[@id="mupMain"]/div[3]/div/section[3]/div[2]/ul/li/div/div/a/@href'))
# Sub_Url = [url_10miles + '?allMeetups=false&radius=50&userFreeform=Dallas%2C+TX&mcId=z75201&mcName=Dallas%2C+TX&sort=default' for url_10miles in Sub_Url_10miles]
# random_lst = list(range(0,len(Sub_Url)))
# random.shuffle(random_lst)

# %%
print(Categories)
# Out:
# ['Outdoors & Adventure', 'Tech', 'Family', 'Health & Wellness', 'Sports & Fitness', 'Learning', 'Photography', 'Food & Drink', 'Writing', 'Language & Culture', 'Music', 'Movements', 'LGBTQ', 'Film', 'Sci-Fi & Games', 'Beliefs', 'Arts', 'Book Clubs', 'Dance', 'Pets', 'Hobbies & Crafts', 'Fashion & Beauty', 'Social', 'Career & Business']

# %%
Sub_Url_raw = list(content.xpath('//*[@id="gatsby-focus-wrapper"]//div[@class="categoryGridList css-1q80wuk"]//a/@href'))
Sub_Url = [x.replace('/find/','https://www.meetup.com/find/us--tx--dallas/') for x in Sub_Url_raw]
Sub_Url
# Out:
# ['https://www.meetup.com/find/us--tx--dallas/outdoors-adventure',
#  'https://www.meetup.com/find/us--tx--dallas/tech',
#  'https://www.meetup.com/find/us--tx--dallas/parents-family',
#  'https://www.meetup.com/find/us--tx--dallas/health-wellness',
#  'https://www.meetup.com/find/us--tx--dallas/sports-fitness',
#  'https://www.meetup.com/find/us--tx--dallas/education',
#  'https://www.meetup.com/find/us--tx--dallas/photography',
#  'https://www.meetup.com/find/us--tx--dallas/food',
#  'https://www.meetup.com/find/us--tx--dallas/writing',
#  'https://www.meetup.com/find/us--tx--dallas/language',
#  'https://www.meetup.com/find/us--tx--dallas/music',
#  'https://www.meetup.com/find/us--tx--dallas/movements',
#  'https://www.meetup.com/find/us--tx--dallas/lgbtq',
#  'https://www.meetup.com/find/us--tx--dallas/film',
#  'https://www.meetup.com/find/us--tx--dallas/games-sci-fi',
#  'https://www.meetup.com/find/us--tx--dallas/beliefs',
#  'https://www.meetup.com/find/us--tx--dallas/arts-culture',
#  'https://www.meetup.com/find/us--tx--dallas/book-clubs',
#  'https://www.meetup.com/find/us--tx--dallas/dancing',
#  'https://www.meetup.com/find/us--tx--dallas/pets',
#  'https://www.meetup.com/find/us--tx--dallas/hobbies-crafts',
#  'https://www.meetup.com/find/us--tx--dallas/fashion-beauty',
#  'https://www.meetup.com/find/us--tx--dallas/social',
#  'https://www.meetup.com/find/us--tx--dallas/career-business']

# %% [markdown]
# ### [Family events](https://www.meetup.com/find/us--tx--dallas/parents-family)

# %%
import requests

url = 'https://api.meetup.com/gql'

data = {"operationName":"categoryEvents","variables":{"topicId":232,"startDateRange":"2020-09-01T14:04:39","lat":32.80,"lon":-96.80,"first":20},"query":"query categoryEvents($lat: Float!, $lon: Float!, $topicId: Int, $startDateRange: DateTime, $endDateRange: DateTime, $first: Int, $after: String) {\n  searchEvents: upcomingEvents(search: {lat: $lat, lon: $lon, categoryId: $topicId, startDateRange: $startDateRange, endDateRange: $endDateRange}, input: {first: $first, after: $after}) {\n    pageInfo {\n      hasNextPage\n      endCursor\n      __typename\n    }\n    count\n    recommendationSource\n    recommendationId\n    edges {\n      node {\n        group {\n          name\n          urlname\n          timezone\n          link\n          groupPhoto {\n            id\n            baseUrl\n            __typename\n          }\n          __typename\n        }\n        description\n        fee\n        feeCurrency\n        id\n        title\n        dateTime\n        eventPhoto {\n          id\n          baseUrl\n          __typename\n        }\n        venue {\n          id\n          name\n          address1\n          address2\n          address3\n          city\n          state\n          country\n          zip\n          phone\n          venueType\n          __typename\n        }\n        going {\n          totalCount\n          edges {\n            metadata {\n              memberGroupPhoto {\n                thumbUrl\n                __typename\n              }\n              __typename\n            }\n            __typename\n          }\n          __typename\n        }\n        link\n        isSaved\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
headers = {'authority':'api.meetup.com',
           'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36'}

r = requests.post(url,headers = headers,json = data)
events_json = r.json()
events_json['data']['searchEvents']['edges'][0]
# Out:
# {'node': {'group': {'name': 'DFW Anything Social',
#    'urlname': 'DFW-Anything-Social',
#    'timezone': 'America/Chicago',
#    'link': 'https://www.meetup.com/DFW-Anything-Social',
#    'groupPhoto': {'id': '492041357',
#     'baseUrl': 'https://secure-content.meetupstatic.com/images/classic-events/',
#     '__typename': 'Image'},
#    '__typename': 'ChapstickGroup'},
#   'description': None,
#   'fee': None,
#   'feeCurrency': None,
#   'id': '272846904',
#   'title': 'First presidential Debate',
#   'dateTime': '2020-09-29T19:30-05:00[US/Central]',
#   'eventPhoto': {'id': '492029253',
#    'baseUrl': 'https://secure-content.meetupstatic.com/images/classic-events/',
#    '__typename': 'Image'},
#   'venue': {'id': '23650299',
#    'name': 'TBD',
#    'address1': 'TBD',
#    'address2': None,
#    'address3': None,
#    'city': 'Dallas',
#    'state': 'TX',
#    'country': 'us',
#    'zip': '',
#    'phone': None,
#    'venueType': None,
#    '__typename': 'ChapstickVenue'},
#   'going': {'totalCount': 2,
#    'edges': [{'metadata': {'memberGroupPhoto': {'thumbUrl': 'https://secure.meetupstatic.com/photos/member/2/8/4/9/thumb_297070313.jpeg',
#        '__typename': 'PhotoInfo'},
#       '__typename': 'ChapstickRsvpEdgeMetadata'},
#      '__typename': 'ChapstickRsvpEdge'},
#     {'metadata': {'memberGroupPhoto': {'thumbUrl': 'https://secure.meetupstatic.com/photos/member/b/8/0/8/thumb_286367112.jpeg',
#        '__typename': 'PhotoInfo'},
#       '__typename': 'ChapstickRsvpEdgeMetadata'},
#      '__typename': 'ChapstickRsvpEdge'}],
#    '__typename': 'ChapstickGoingRsvpConnection'},
#   'link': 'https://www.meetup.com/DFW-Anything-Social/events/272846904/',
#   'isSaved': False,
#   '__typename': 'ChapstickEvent'},
#  '__typename': 'RootChapstickEventsEdge'}

# %%
len(events_json['data']['searchEvents']['edges'])
# Out:
# 6

# %%
import requests

url = 'https://api.meetup.com/gql'

data = {"operationName":"categoryEvents","variables":{"topicId":232,"startDateRange":"2020-05-21T14:04:39","lat":32.84,"lon":-96.7,"first":20},"query":"query categoryEvents($lat: Float!, $lon: Float!, $topicId: Int, $startDateRange: DateTime, $endDateRange: DateTime, $first: Int, $after: String) {\n  searchEvents: upcomingEvents(search: {lat: $lat, lon: $lon, categoryId: $topicId, startDateRange: $startDateRange, endDateRange: $endDateRange}, input: {first: $first, after: $after}) {\n    pageInfo {\n      hasNextPage\n      endCursor\n      __typename\n    }\n    count\n    recommendationSource\n    recommendationId\n    edges {\n      node {\n        group {\n          name\n          urlname\n          timezone\n          link\n          groupPhoto {\n            id\n            baseUrl\n            __typename\n          }\n          __typename\n        }\n        description\n        fee\n        feeCurrency\n        id\n        title\n        dateTime\n        eventPhoto {\n          id\n          baseUrl\n          __typename\n        }\n        venue {\n          id\n          name\n          address1\n          address2\n          address3\n          city\n          state\n          country\n          zip\n          phone\n          venueType\n          __typename\n        }\n        going {\n          totalCount\n          edges {\n            metadata {\n              memberGroupPhoto {\n                thumbUrl\n                __typename\n              }\n              __typename\n            }\n            __typename\n          }\n          __typename\n        }\n        link\n        isSaved\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}
headers = {'authority':'api.meetup.com',
           'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36'}

r = requests.post(url,headers = headers,json = data)
events_json = r.json()
events_json['data']['searchEvents']['edges'][0]
# Out:
# {'node': {'group': {'name': 'DFW Anything Social',
#    'urlname': 'DFW-Anything-Social',
#    'timezone': 'America/Chicago',
#    'link': 'https://www.meetup.com/DFW-Anything-Social',
#    'groupPhoto': {'id': '492041357',
#     'baseUrl': 'https://secure-content.meetupstatic.com/images/classic-events/',
#     '__typename': 'Image'},
#    '__typename': 'ChapstickGroup'},
#   'description': None,
#   'fee': None,
#   'feeCurrency': None,
#   'id': '272846904',
#   'title': 'First presidential Debate',
#   'dateTime': '2020-09-29T19:30-05:00[US/Central]',
#   'eventPhoto': {'id': '492029253',
#    'baseUrl': 'https://secure-content.meetupstatic.com/images/classic-events/',
#    '__typename': 'Image'},
#   'venue': {'id': '23650299',
#    'name': 'TBD',
#    'address1': 'TBD',
#    'address2': None,
#    'address3': None,
#    'city': 'Dallas',
#    'state': 'TX',
#    'country': 'us',
#    'zip': '',
#    'phone': None,
#    'venueType': None,
#    '__typename': 'ChapstickVenue'},
#   'going': {'totalCount': 2,
#    'edges': [{'metadata': {'memberGroupPhoto': {'thumbUrl': 'https://secure.meetupstatic.com/photos/member/2/8/4/9/thumb_297070313.jpeg',
#        '__typename': 'PhotoInfo'},
#       '__typename': 'ChapstickRsvpEdgeMetadata'},
#      '__typename': 'ChapstickRsvpEdge'},
#     {'metadata': {'memberGroupPhoto': {'thumbUrl': 'https://secure.meetupstatic.com/photos/member/b/8/0/8/thumb_286367112.jpeg',
#        '__typename': 'PhotoInfo'},
#       '__typename': 'ChapstickRsvpEdgeMetadata'},
#      '__typename': 'ChapstickRsvpEdge'}],
#    '__typename': 'ChapstickGoingRsvpConnection'},
#   'link': 'https://www.meetup.com/DFW-Anything-Social/events/272846904/',
#   'isSaved': False,
#   '__typename': 'ChapstickEvent'},
#  '__typename': 'RootChapstickEventsEdge'}

# %% [markdown]
# ### [Outdoors & Adventure events](https://www.meetup.com/find/outdoors-adventure)

# %%
import requests,json
import pandas as pd

url = 'https://api.meetup.com/gql'

data = {"operationName":"categoryEvents","variables":{"topicId":242,"startDateRange":"2020-09-01T12:54:14","lat":32.84,"lon":-96.7,"first":100},"query":"query categoryEvents($lat: Float!, $lon: Float!, $topicId: Int, $startDateRange: DateTime, $endDateRange: DateTime, $first: Int, $after: String) {\n  searchEvents: upcomingEvents(search: {lat: $lat, lon: $lon, categoryId: $topicId, startDateRange: $startDateRange, endDateRange: $endDateRange}, input: {first: $first, after: $after}) {\n    pageInfo {\n      hasNextPage\n      endCursor\n      __typename\n    }\n    count\n    recommendationSource\n    recommendationId\n    edges {\n      node {\n        group {\n          name\n          urlname\n          timezone\n          link\n          groupPhoto {\n            id\n            baseUrl\n            __typename\n          }\n          __typename\n        }\n        description\n        fee\n        feeCurrency\n        id\n        title\n        dateTime\n        eventPhoto {\n          id\n          baseUrl\n          __typename\n        }\n        venue {\n          id\n          name\n          address1\n          address2\n          address3\n          city\n          state\n          country\n          zip\n          phone\n          venueType\n          __typename\n        }\n        going {\n          totalCount\n          edges {\n            metadata {\n              memberGroupPhoto {\n                thumbUrl\n                __typename\n              }\n              __typename\n            }\n            __typename\n          }\n          __typename\n        }\n        link\n        isSaved\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}

    headers = {'authority':'api.meetup.com',
           'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36'}

r = requests.post(url,json = data)
events_json = r.json()
print(len(events_json['data']['searchEvents']['edges']))
# events_json['data']['searchEvents']['edges'][0]
# Out:
# 59

# %%
import requests,json
import pandas as pd

url = 'https://api.meetup.com/gql'

data = {"operationName":"categoryEvents","variables":{"topicId":242,"startDateRange":"2020-09-01T12:54:14","lat":32.84,"lon":-96.7,"first":100},"query":"query categoryEvents($lat: Float!, $lon: Float!, $topicId: Int, $startDateRange: DateTime, $endDateRange: DateTime, $first: Int, $after: String) {\n  searchEvents: upcomingEvents(search: {lat: $lat, lon: $lon, categoryId: $topicId, startDateRange: $startDateRange, endDateRange: $endDateRange}, input: {first: $first, after: $after}) {\n    pageInfo {\n      hasNextPage\n      endCursor\n      __typename\n    }\n    count\n    recommendationSource\n    recommendationId\n    edges {\n      node {\n        group {\n          name\n          urlname\n          timezone\n          link\n          groupPhoto {\n            id\n            baseUrl\n            __typename\n          }\n          __typename\n        }\n        description\n        fee\n        feeCurrency\n        id\n        title\n        dateTime\n        eventPhoto {\n          id\n          baseUrl\n          __typename\n        }\n        venue {\n          id\n          name\n          address1\n          address2\n          address3\n          city\n          state\n          country\n          zip\n          phone\n          venueType\n          __typename\n        }\n        going {\n          totalCount\n          edges {\n            metadata {\n              memberGroupPhoto {\n                thumbUrl\n                __typename\n              }\n              __typename\n            }\n            __typename\n          }\n          __typename\n        }\n        link\n        isSaved\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"}

headers = {'authority':'api.meetup.com', 
           'content-type': 'application/json',
           'content-length':1706,
           'path':'/gql',
           'accept-encoding': 'gzip, deflate, br',
           'apollographql-client-name': 'build-meetup web',
           'referer': 'https://www.meetup.com/find/outdoors-adventure',
           'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36'}

r = requests.post(url,json = data)
events_json = r.json()
print(len(events_json['data']['searchEvents']['edges']))
# events_json['data']['searchEvents']['edges'][0]
# Out:
# {'group': {'name': 'Dallas Pedals & Pints',
#   'urlname': 'dallas-pedals-and-pints',
#   'timezone': 'America/Chicago',
#   'link': 'https://www.meetup.com/dallas-pedals-and-pints',
#   'groupPhoto': {'id': '473205737',
#    'baseUrl': 'https://secure-content.meetupstatic.com/images/classic-events/',
#    '__typename': 'Image'},
#   '__typename': 'ChapstickGroup'},
#  'description': None,
#  'fee': None,
#  'feeCurrency': None,
#  'id': '273042539',
#  'title': "Alt-Labor Day Ride - Manny's Restaurant,  NE corner Mockingbird-Abrams",
#  'dateTime': '2020-09-07T08:00-05:00[US/Central]',
#  'eventPhoto': None,
#  'venue': {'id': '26982148',
#   'name': "Manny's Uptown Tex-Mex Restaurante",
#   'address1': '6465 E Mockingbird Ln',
#   'address2': None,
#   'address3': None,
#   'city': 'Dallas',
#   'state': 'TX',
#   'country': 'us',
#   'zip': '75214',
#   'phone': None,
#   'venueType': None,
#   '__typename': 'ChapstickVenue'},
#  'going': {'totalCount': 3,
#   'edges': [{'metadata': {'memberGroupPhoto': {'thumbUrl': 'https://secure.meetupstatic.com/photos/member/4/b/1/4/thumb_256999220.jpeg',
#       '__typename': 'PhotoInfo'},
#      '__typename': 'ChapstickRsvpEdgeMetadata'},
#     '__typename': 'ChapstickRsvpEdge'},
#    {'metadata': {'memberGroupPhoto': {'thumbUrl': 'https://secure.meetupstatic.com/photos/member/b/a/4/3/thumb_292847683.jpeg',
#       '__typename': 'PhotoInfo'},
#      '__typename': 'ChapstickRsvpEdgeMetadata'},
#     '__typename': 'ChapstickRsvpEdge'},
#    {'metadata': {'memberGroupPhoto': {'thumbUrl': 'https://secure.meetupstatic.com/photos/member/2/8/5/a/thumb_294250330.jpeg',
#       '__typename': 'PhotoInfo'},
#      '__typename': 'ChapstickRsvpEdgeMetadata'},
#     '__typename': 'ChapstickRsvpEdge'}],
#   '__typename': 'ChapstickGoingRsvpConnection'},
#  'link': 'https://www.meetup.com/dallas-pedals-and-pints/events/273042539/',
#  'isSaved': False,
#  '__typename': 'ChapstickEvent'}

# %% [markdown]
# ### Downloader

# %%
from datetime import datetime,timezone
now = datetime.strftime(datetime.now(timezone.utc), "%Y-%m-%dT%H:%M:%S")
now
# Out:
# '2020-09-06T21:42:51'

# %%
events = []
for edge in events_json['data']['searchEvents']['edges']:
    event = {}
    event['Title'] = edge['node']['title']
    event['Date'] = edge['node']['dateTime']
    event['Group Name'] = edge['node']['group']['name']
    try:
        event['Place'] = edge['node']['venue']['name']
    except:
        event['Place'] = None
    try:
        event['Zip'] = edge['node']['venue']['zip']
        event['address1'] = edge['node']['venue']['address1']
    except:
        event['Zip'] = None
        event['address1'] = None
    event['Url'] = edge['node']['link']
    events.append(event)

# %%
df = pd.DataFrame(events)
df
# Out:
#                                                 Title  \
# 0   Labor Day, 3 Nations, 47 Mile Drop Ride, Dalla...
# 1   Alt-Labor Day Ride - Manny's Restaurant,  NE c...
# 2              Shifty Free Wheelers Monday Night Ride
# 3                          The Morning Ride - Tuesday
# 4   Travel Talk Tuesdays: Safety in the time of COVID
# 5                           Tuesday Evening Bike Ride
# 6                                          Pint Night
# 7   Learn about the Heard Museum and wildlife sanc...
# 8                        The Morning Ride - Wednesday
# 9                         The Morning Ride - Thursday
# 10                        Paddling on White Rock Lake
# 11                           GDB Downtown Dallas Ride
# 12                                Thirsty Thursday’s
# 13    Backpacking For Beginners Live Virtual Workshop
# 14  Second Saturday Shorline Spruce-up (or SSSS as...
# 15  Adriatic Trip : Croatia, Slovenia & Bosnia-Her...
# 16    Backpacking For Beginners Live Virtual Workshop
# 17  Adventure to Machu Picchu with Rainbow Mountai...
# 18    Backpacking For Beginners Live Virtual Workshop
# 19                     Moab and Arches Hiking Weekend
#
#                                   Date                        Group Name  \
# 0   2020-09-07T07:30-05:00[US/Central]             Dallas Pedals & Pints
# 1   2020-09-07T08:00-05:00[US/Central]             Dallas Pedals & Pints
# 2   2020-09-07T19:00-05:00[US/Central]              Dallas Critical Mass
# 3   2020-09-08T08:00-05:00[US/Central]             Dallas Pedals & Pints
# 4   2020-09-08T17:30-05:00[US/Central]       Dallas International Travel
# 5   2020-09-08T18:00-05:00[US/Central]         Greater Dallas Bicyclists
# 6   2020-09-08T18:30-05:00[US/Central]             Dallas Pedals & Pints
# 7   2020-09-08T19:00-05:00[US/Central]                Dallas Sierra Club
# 8   2020-09-09T08:00-05:00[US/Central]             Dallas Pedals & Pints
# 9   2020-09-10T08:00-05:00[US/Central]             Dallas Pedals & Pints
# 10  2020-09-10T18:00-05:00[US/Central]              North Texas Outdoors
# 11  2020-09-10T18:30-05:00[US/Central]         Greater Dallas Bicyclists
# 12  2020-09-10T19:00-05:00[US/Central]             Dallas Pedals & Pints
# 13  2020-09-10T19:00-05:00[US/Central]         Explorer Chicks of Dallas
# 14  2020-09-12T09:00-05:00[US/Central]                    KayakPower.com
# 15  2020-09-12T19:00-05:00[US/Central]  Dallas Travel & Activities Group
# 16  2020-09-13T19:00-05:00[US/Central]         Explorer Chicks of Dallas
# 17  2020-09-14T13:00-05:00[US/Central]         Explorer Chicks of Dallas
# 18  2020-09-14T19:00-05:00[US/Central]         Explorer Chicks of Dallas
# 19  2020-09-17T08:00-05:00[US/Central]         Explorer Chicks of Dallas
#
#                                   Place    Zip  \
# 0                                  None   None
# 1    Manny's Uptown Tex-Mex Restaurante  75214
# 2           Deep Ellum - DeepEllums.com  75226
# 3   Ridgewood/Belcher Recreation Center  75214
# 4                          Online event
# 5                          Online event
# 6                        The Lake House  75214
# 7                          Online event
# 8   Ridgewood/Belcher Recreation Center  75214
# 9   Ridgewood/Belcher Recreation Center  75214
# 10                     521 E Lawther Dr  75218
# 11             Office Depot Parking Lot  75243
# 12        White Rock Alehouse & Brewery  75214
# 13                         Online event
# 14                          SSSS at WRL  75214
# 15                                 None   None
# 16                         Online event
# 17                                 None   None
# 18                         Online event
# 19                                 None   None
#
#                                         address1  \
# 0                                           None
# 1                          6465 E Mockingbird Ln
# 2                               2923 Commerce St
# 3                                 6818 Fisher Rd
# 4
# 5
# 6   7510 East Northwest Highway Dallas, Tx 75214
# 7
# 8                                 6818 Fisher Rd
# 9                                 6818 Fisher Rd
# 10                              521 E Lawther Dr
# 11        11615 N Central Expy, Dallas, TX 75243
# 12                          7331 Gaston Ave #100
# 13
# 14                       4100 West Lawther Drive
# 15                                          None
# 16
# 17                                          None
# 18
# 19                                          None
#
#                                                   Url
# 0   https://www.meetup.com/dallas-pedals-and-pints...
# 1   https://www.meetup.com/dallas-pedals-and-pints...
# 2   https://www.meetup.com/Dallas-Critical-Mass/ev...
# 3   https://www.meetup.com/dallas-pedals-and-pints...
# 4   https://www.meetup.com/Dallas-International-Tr...
# 5   https://www.meetup.com/Greater-Dallas-Bicyclis...
# 6   https://www.meetup.com/dallas-pedals-and-pints...
# 7   https://www.meetup.com/DallasSierraClub/events...
# 8   https://www.meetup.com/dallas-pedals-and-pints...
# 9   https://www.meetup.com/dallas-pedals-and-pints...
# 10  https://www.meetup.com/North-Texas-Outdoors/ev...
# 11  https://www.meetup.com/Greater-Dallas-Bicyclis...
# 12  https://www.meetup.com/dallas-pedals-and-pints...
# 13  https://www.meetup.com/Explorer-Chicks-of-Dall...
# 14  https://www.meetup.com/KayakPower/events/ltnbg...
# 15  https://www.meetup.com/Dallas-Travel-And-Activ...
# 16  https://www.meetup.com/Explorer-Chicks-of-Dall...
# 17  https://www.meetup.com/Explorer-Chicks-of-Dall...
# 18  https://www.meetup.com/Explorer-Chicks-of-Dall...
# 19  https://www.meetup.com/Explorer-Chicks-of-Dall...

# %%
df.Url[19]
# Out:
# 'https://www.meetup.com/Explorer-Chicks-of-Dallas/events/265487117/'
